# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Files, Folders & OS (Need) Exercises</span></div>

# %% [markdown]
# ## Exercise 1

# %%
import os
import glob
import shutil
import numpy as np

# %%
#Task 1
date_info = {
'jan': '01', 'feb': '02', 'mar': '03',
'apr': '04', 'may': '05', 'jun': '06',
'jul': '07', 'aug': '08', 'sep': '09',
'oct': '10', 'nov': '11', 'dec': '12'
}

path = os.path.join('Users','chengzuting','Desktop','os-collaboration-exercise-data','oct-08_singapore.txt')
old_file_name = path.split(os.path.sep)[-1]
mm, info = old_file_name.split('-')
dd, city = info.split('_')
new_file_name = f'{date_info['oct']}-{dd}-{city}'
print(new_file_name)
# Out:
# 10-08-singapore.txt

# %%
#Task 2
date_info = {
'jan': '01', 'feb': '02', 'mar': '03',
'apr': '04', 'may': '05', 'jun': '06',
'jul': '07', 'aug': '08', 'sep': '09',
'oct': '10', 'nov': '11', 'dec': '12'
}

path = os.path.join('Users','chengzuting','Desktop','os-collaboration-exercise-data','oct-08_singapore.txt')
def renamemyfile(old_file_name):
    old_file_name = path.split(os.path.sep)[-1]
    mm, info = oldfilename.split('-')
    dd, city = info.split('_')
    new_file_name = f'{date_info['oct']}-{dd}-{city}'
print(new_file_name)
# Out:
# 10-08-singapore.txt

# %%
#Task 3 
date_info = {
'jan': '01', 'feb': '02', 'mar': '03',
'apr': '04', 'may': '05', 'jun': '06',
'jul': '07', 'aug': '08', 'sep': '09',
'oct': '10', 'nov': '11', 'dec': '12'
}

file_list = ['oct-08_singapore.txt', 'jul-10_cairo.txt', 'may-15_dhaka.txt',
 'may-13_cairo.txt', 'oct-21_cairo.txt', 'jan-10_singapore.txt',
 'jun-20_tokyo.txt', 'aug-06_jakarta.txt', 'dec-21_karachi.txt',
 'jan-01_tokyo.txt']

path = os.path.join('Users','chengzuting','Desktop','os-collaboration-exercise-data')

def rename_my_file(old_file_name):
    mm, info = old_file_name.split('-')
    dd, city = info.split('_')
    month = date_info[mm]
    new_file_name = f'{month}-{dd}-{city}'
    return new_file_name

for old_file_name in file_list:
    new_file_name = rename_my_file(old_file_name)
    print(f'{old_file_name} ----> {new_file_name}')
# Out:
# oct-08_singapore.txt ----> 10-08-singapore.txt
# jul-10_cairo.txt ----> 07-10-cairo.txt
# may-15_dhaka.txt ----> 05-15-dhaka.txt
# may-13_cairo.txt ----> 05-13-cairo.txt
# oct-21_cairo.txt ----> 10-21-cairo.txt
# jan-10_singapore.txt ----> 01-10-singapore.txt
# jun-20_tokyo.txt ----> 06-20-tokyo.txt
# aug-06_jakarta.txt ----> 08-06-jakarta.txt
# dec-21_karachi.txt ----> 12-21-karachi.txt
# jan-01_tokyo.txt ----> 01-01-tokyo.txt

# %%
#Task 4

date_info = {
'jan': '01', 'feb': '02', 'mar': '03',
'apr': '04', 'may': '05', 'jun': '06',
'jul': '07', 'aug': '08', 'sep': '09',
'oct': '10', 'nov': '11', 'dec': '12'
}

file_list = ['oct-08_singapore.txt', 'jul-10_cairo.txt', 'may-15_dhaka.txt',
 'may-13_cairo.txt', 'oct-21_cairo.txt', 'jan-10_singapore.txt',
 'jun-20_tokyo.txt', 'aug-06_jakarta.txt', 'dec-21_karachi.txt',
 'jan-01_tokyo.txt']

Glob = glob.glob('os-collaboration-exercise-data/*.txt') #list
prefix_to_remove = 'os-collaboration-exercise-data/'
all_file = [s.removeprefix(prefix_to_remove) for s in Glob]

def rename_my_file(old_file_name):
    mm, info = old_file_name.split('-')
    dd, city = info.split('_')
    month = date_info[mm]
    new_file_name = f'{month}-{dd}-{city}'
    return new_file_name

for old_file_name in all_file:
    new_file_name = rename_my_file(old_file_name)
    oldfilename = 'os-collaboration-exercise-data/'+ old_file_name 
    newfilename = 'os-collaboration-exercise-data/'+ new_file_name
    os.rename(oldfilename, newfilename) 

#must always provide the path for all file
#can try to optimise 
#try & except to check for existing files

# %%
#Task 5
city_list = ['Cairo', 'Dhaka', 'Jakarta', 'Karachi', 'Manila',
 'Melbourne', 'Osaka', 'Shanghai', 'Singapore', 'Tokyo']
for city in city_list:
    path = os.path.join('os-collaboration-exercise-data', city)
    print(f'Creating {path}')
    os.mkdir(path)
# Out:
# Creating os-collaboration-exercise-data/Cairo
# Creating os-collaboration-exercise-data/Dhaka
# Creating os-collaboration-exercise-data/Jakarta
# Creating os-collaboration-exercise-data/Karachi
# Creating os-collaboration-exercise-data/Manila
# Creating os-collaboration-exercise-data/Melbourne
# Creating os-collaboration-exercise-data/Osaka
# Creating os-collaboration-exercise-data/Shanghai
# Creating os-collaboration-exercise-data/Singapore
# Creating os-collaboration-exercise-data/Tokyo

# %%
#Task 6

Glob_cairo = glob.glob('os-collaboration-exercise-data/*cairo.txt') 
#list of cairo file

for cairo_file in Glob_cairo:
    path_to_destination = os.path.join('os-collaboration-exercise-data/Cairo', cairo_file)
    shutil.copy(cairo_file, 'os-collaboration-exercise-data/Cairo') #(source, destination)
    print(f'Copied {cairo_file} to {path_to_destination}') #must show path
# Out:
# Copied os-collaboration-exercise-data/09-18-cairo.txt to os-collaboration-exercise-data/Cairo/os-collaboration-exercise-data/09-18-cairo.txt
# Copied os-collaboration-exercise-data/04-06-cairo.txt to os-collaboration-exercise-data/Cairo/os-collaboration-exercise-data/04-06-cairo.txt
# Copied os-collaboration-exercise-data/03-06-cairo.txt to os-collaboration-exercise-data/Cairo/os-collaboration-exercise-data/03-06-cairo.txt
# Copied os-collaboration-exercise-data/01-03-cairo.txt to os-collaboration-exercise-data/Cairo/os-collaboration-exercise-data/01-03-cairo.txt
# Copied os-collaboration-exercise-data/03-12-cairo.txt to os-collaboration-exercise-data/Cairo/os-collaboration-exercise-data/03-12-cairo.txt
# Copied os-collaboration-exercise-data/04-12-cairo.txt to os-collaboration-exercise-data/Cairo/os-collaboration-exercise-data/04-12-cairo.txt
# ...

# %%
#Task 7 
city_list = ['Cairo', 'Dhaka', 'Jakarta', 'Karachi', 'Manila',
 'Melbourne', 'Osaka', 'Shanghai', 'Singapore', 'Tokyo']

Glob = glob.glob('os-collaboration-exercise-data/*.txt')

for source_file in Glob:
    filename = os.path.basename(source_file) #get rid of the previous path folder, only left with 
    for city in city_list:
        if city.lower() in filename:   # city in city_list must be converted to lowercase
            folder_path = os.path.join('os-collaboration-exercise-data', city)
            path_to_destination = os.path.join(folder_path, filename)
            shutil.move(source_file, path_to_destination)
            print(f'Moved {filename} → {path_to_destination}')
# Out:
# Moved 07-28-dhaka.txt → os-collaboration-exercise-data/Dhaka/07-28-dhaka.txt
# Moved 10-16-shanghai.txt → os-collaboration-exercise-data/Shanghai/10-16-shanghai.txt
# Moved 10-18-dhaka.txt → os-collaboration-exercise-data/Dhaka/10-18-dhaka.txt
# Moved 09-18-cairo.txt → os-collaboration-exercise-data/Cairo/09-18-cairo.txt
# Moved 12-15-melbourne.txt → os-collaboration-exercise-data/Melbourne/12-15-melbourne.txt
# Moved 07-09-shanghai.txt → os-collaboration-exercise-data/Shanghai/07-09-shanghai.txt
# Moved 04-05-singapore.txt → os-collaboration-exercise-data/Singapore/04-05-singapore.txt
# Moved 04-06-cairo.txt → os-collaboration-exercise-data/Cairo/04-06-cairo.txt
# Moved 05-02-osaka.txt → os-collaboration-exercise-data/Osaka/05-02-osaka.txt
# Moved 07-07-osaka.txt → os-collaboration-exercise-data/Osaka/07-07-osaka.txt
# Moved 01-01-osaka.txt → os-collaboration-exercise-data/Osaka/01-01-osaka.txt
# Moved 10-11-shanghai.txt → os-collaboration-exercise-data/Shanghai/10-11-shanghai.txt
# ...
